# %%
import pandas  as pd
import seaborn as sns
import numpy as np

# %%
auto=pd.read_csv("C:/Users/Sys7/Downloads/auto_data.csv")
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto_1=auto.corr()
sns.heatmap(auto_1,annot=True)
# Out:
# C:\Users\Sys7\AppData\Local\Temp\ipykernel_1556\2412801839.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   auto_1=auto.corr()
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
mean_values=auto[["mpg","cylinders","displacement","weight","acceleration","model_year","origin"]].mean()
print(mean_values)
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model_year        76.010050
# origin             1.572864
# dtype: float64

# %%
plt.bar(mean_values.index,mean_values)
plt.xlabel('headers')
plt.ylabel('mean value')
plt.title('mean value representation')
plt.show()

# %%
plt.plot(mean_values.index,mean_values)
plt.xlabel('headers')
plt.ylabel('mean value')
plt.title('mean value representation')
plt.show()

# %%
plt.pie(mean_values,labels=mean_values.index,autopct='%1.1f%%')
plt.title('mean value representation')
plt.show()

# %%
sns.pairplot(data=auto,vars=['mpg','weight'],height=4,hue='origin')

plt.show()

# %%
auto['horsepower']=pd.to_numeric(auto['horsepower'],errors='coerce')
result=auto[(auto["acceleration"]>15) & (auto["horsepower"]<170)]['name']
print(result)
# Out:
# 15                  plymouth duster
# 16                       amc hornet
# 17                    ford maverick
# 19     volkswagen 1131 deluxe sedan
# 20                      peugeot 504
#                    ...
# 392                chevrolet camaro
# 393                 ford mustang gl
# 394                       vw pickup
# 396                     ford ranger
# 397                      chevy s-10
# Name: name, Length: 211, dtype: object

# %%
group_by=auto.groupby('cylinders').size()
print(group_by)
# Out:
# cylinders
# 3      4
# 4    204
# 5      3
# 6     84
# 8    103
# dtype: int64

# %%
vehicle_counts=auto.groupby('model_year').count()
print(vehicle_counts)
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# model_year
# 70           29         29            29          29      29            29
# 71           28         28            28          27      28            28
# 72           28         28            28          28      28            28
# 73           40         40            40          40      40            40
# 74           27         27            27          26      27            27
# 75           30         30            30          30      30            30
# 76           34         34            34          34      34            34
# 77           28         28            28          28      28            28
# 78           36         36            36          36      36            36
# 79           29         29            29          29      29            29
# 80           29         29            29          27      29            29
# ...
