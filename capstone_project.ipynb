# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
m=pd.read_csv("C:/Users/Sys7/Desktop/product data.csv")
m
# Out:
#       txno     txndate     custno   amount            category  \
# 0        0  06-26-2011    4007024    40.33  Exercise & Fitness
# 1        1  05-26-2011    4006742   198.44  Exercise & Fitness
# 2        2  06-01-2011    4009775     5.58  Exercise & Fitness
# 3        3  06-05-2011    4002199   198.19          Gymnastics
# 4        4  12-17-2011    4002613    98.81         Team Sports
# ...    ...         ...        ...      ...                 ...
# 5252  5252  04-06-2011    4000744     9.83               Games
# 5253  5253  10-09-2011    4007968    90.91  Outdoor Recreation
# 5254  5254  03-04-2011    4004453    51.19         Team Sports
# 5255  5255  01-11-2011    4003325   128.93  Outdoor Recreation
# 5256  5256  01-08-2011    4006213    40.02               Games
#
#                                 product                  city          state  \
# 0            Cardio Machine Accessories           Clarksville      Tennessee
# ...

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5257 entries, 0 to 5256
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   txno                   5257 non-null   int64
#  1       txndate            5257 non-null   object
#  2      custno              5257 non-null   int64
#  3    amount                5257 non-null   float64
#  4         category         5257 non-null   object
#  5          product         5257 non-null   object
#  6                    city  5257 non-null   object
#  7        state             5257 non-null   object
#  8        spendby           5257 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 369.8+ KB

# %%
m.describe()
# Out:
#               txno        custno       amount
# count  5257.000000  5.257000e+03  5257.000000
# mean   2628.000000  4.004907e+06   102.809819
# std    1517.709513  2.861628e+03    56.635753
# min       0.000000  4.000001e+06     5.010000
# 25%    1314.000000  4.002422e+06    53.600000
# 50%    2628.000000  4.004884e+06   102.360000
# 75%    3942.000000  4.007361e+06   152.180000
# max    5256.000000  4.009999e+06   199.990000

# %%
m.head(10)
# Out:
#    txno     txndate     custno   amount                category  \
# 0     0  06-26-2011    4007024    40.33      Exercise & Fitness
# 1     1  05-26-2011    4006742   198.44      Exercise & Fitness
# 2     2  06-01-2011    4009775     5.58      Exercise & Fitness
# 3     3  06-05-2011    4002199   198.19              Gymnastics
# 4     4  12-17-2011    4002613    98.81             Team Sports
# 5     5  02-14-2011    4007591   193.63      Outdoor Recreation
# 6     6  10-28-2011    4002190    27.89                 Puzzles
# 7     7  07-14-2011    4002964    96.01  Outdoor Play Equipment
# 8     8  01-17-2011    4007361    10.44           Winter Sports
# 9     9  05-17-2011    4004798   152.46                 Jumping
#
#                              product                  city           state  \
# 0         Cardio Machine Accessories           Clarksville       Tennessee
# 1               Weightlifting Gloves            Long Beach      California
# ...

# %%
# %matplotlib inline

# %%
column_names=m.columns
print(column_names)
# Out:
# Index(['txno', '    txndate', '   custno', ' amount', '      category',
#        '       product', '                 city', '     state',
#        '     spendby'],
#       dtype='object')

# %%
sns.heatmap(m.isnull(),yticklabels=False,cbar= False,cmap= 'viridis')
# Out:
# <Axes: >

# %%
sns.countplot(x='     spendby',data=m)
# Out:
# <Axes: xlabel='     spendby', ylabel='count'>

# %%
plt.bar(m[' amount'],m['    txndate'])
plt.xlabel('amount')
plt.ylabel('dates')
plt.title('amount spend on date')
plt.show()

# %%
m['month']=pd.to_datetime(m['    txndate'])
print(m['month'])
# Out:
# 0      2011-06-26
# 1      2011-05-26
# 2      2011-06-01
# 3      2011-06-05
# 4      2011-12-17
#           ...
# 5252   2011-04-06
# 5253   2011-10-09
# 5254   2011-03-04
# 5255   2011-01-11
# 5256   2011-01-08
# Name: month, Length: 5257, dtype: datetime64[ns]

# %%
sns.countplot(x='     state',data=m)
plt.xticks(rotation=90)
plt.figure(figsize=(100,60))

# %%
sns.countplot(x='      category',data=m)
plt.xticks(rotation=90)
plt.figure(figsize=(100,60))

# %%
plt.bar(m['     state'],m[' amount'])
plt.xticks(rotation=90)
plt.xlabel('state')
plt.ylabel('amount')
plt.title('amount spend by each state')
plt.show()
